# %%
import pandas as pd

# Load the dataset
dataset_path = 'dataset.csv'
df = pd.read_csv(dataset_path)

# Display the first few rows of the dataset
print(df.head())

# Remove empty rows
df_cleaned = df.dropna(how='all')

# Save the cleaned dataset to a new CSV file
df_cleaned.to_csv('modi_data.csv', index=False)
print("Empty rows removed and new file saved as 'modi_data.csv'.")


print(df.head())
# Out:
#    Customer No  post_21_july_unit  post_21_august_unit  post_21_sep_unit  \
# 0     17459140              216.0                243.0             226.0
# 1     17429223              234.0                320.0             471.0
# 2     17442748              422.0                446.0             475.0
# 3     17446670              106.0                149.0             183.0
# 4     17388330              345.0                344.0             367.0
#
#    post_21_oct_unit  post_21_nov_unit  post_21_dec_unit  post_22_jan_unit  \
# 0             204.0             141.0              96.0             121.0
# 1             395.0             177.0             116.0             114.0
# 2             455.0             290.0             214.0             241.0
# 3             240.0             157.0              62.0              46.0
# 4             349.0             203.0             121.0             129.0
#
#   post_22_feb_unit  post_22_mar_unit  ...  pre_23_mar_unit  pre_23_apr_unit  \
# 0              128             205.0  ...           173.71           217.38
# 1              132             221.0  ...           159.54           263.26
# 2              219             330.0  ...           313.88           361.52
# 3               60             203.0  ...           250.28           260.38
# 4              130             187.0  ...           207.11           227.21
#
#   pre_23_may_unit  pre_23_june_unit  pre_23_jul_unit  pre_23_aug_unit  \
# 0          219.68            230.36           220.78           214.76
# 1          227.17            414.11           310.72           214.30
# 2          369.99            382.54           396.71           391.23
# 3          405.04            356.53           416.28           495.84
# 4          266.44            279.59           324.10           276.81
#
#    pre_23_sep_unit  pre_23_oct_unit  pre_23_nov_unit pre_23_dec_unit
# 0           233.58           213.86           157.63          119.75
# 1           361.11           305.27           128.49          147.13
# 2           429.56           418.07           353.79          311.07
# 3           474.25           425.90           348.05          244.02
# 4           268.33           245.55           183.57          167.16
#
# [5 rows x 31 columns]
# Empty rows removed and new file saved as 'modi_data.csv'.
#    Customer No  post_21_july_unit  post_21_august_unit  post_21_sep_unit  \
# 0     17459140              216.0                243.0             226.0
# 1     17429223              234.0                320.0             471.0
# 2     17442748              422.0                446.0             475.0
# 3     17446670              106.0                149.0             183.0
# 4     17388330              345.0                344.0             367.0
#
#    post_21_oct_unit  post_21_nov_unit  post_21_dec_unit  post_22_jan_unit  \
# 0             204.0             141.0              96.0             121.0
# 1             395.0             177.0             116.0             114.0
# 2             455.0             290.0             214.0             241.0
# 3             240.0             157.0              62.0              46.0
# 4             349.0             203.0             121.0             129.0
#
#   post_22_feb_unit  post_22_mar_unit  ...  pre_23_mar_unit  pre_23_apr_unit  \
# 0              128             205.0  ...           173.71           217.38
# 1              132             221.0  ...           159.54           263.26
# 2              219             330.0  ...           313.88           361.52
# 3               60             203.0  ...           250.28           260.38
# 4              130             187.0  ...           207.11           227.21
#
#   pre_23_may_unit  pre_23_june_unit  pre_23_jul_unit  pre_23_aug_unit  \
# 0          219.68            230.36           220.78           214.76
# 1          227.17            414.11           310.72           214.30
# 2          369.99            382.54           396.71           391.23
# 3          405.04            356.53           416.28           495.84
# 4          266.44            279.59           324.10           276.81
#
#    pre_23_sep_unit  pre_23_oct_unit  pre_23_nov_unit pre_23_dec_unit
# 0           233.58           213.86           157.63          119.75
# 1           361.11           305.27           128.49          147.13
# 2           429.56           418.07           353.79          311.07
# 3           474.25           425.90           348.05          244.02
# 4           268.33           245.55           183.57          167.16
#
# [5 rows x 31 columns]
